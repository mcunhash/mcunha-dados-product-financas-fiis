-- %%
%sql
ALTER TABLE product_dev.financas.analytics_performance_fiis 
SET TBLPROPERTIES (
  'delta.columnMapping.mode' = 'name',
  'delta.minReaderVersion' = '2',
  'delta.minWriterVersion' = '5'
);

-- %%
%sql
ALTER TABLE product_dev.financas.analytics_performance_fiis 
RENAME COLUMN categoria_fii TO segmento_alvo;

-- %%
%sql
ALTER TABLE product_dev.financas.analytics_performance_fiis 
ALTER COLUMN segmento_alvo COMMENT 'Sub-classificação setorial detalhada do fundo (ex: Logística, Shopping, Lajes Corporativas, Papel, FoF).';
