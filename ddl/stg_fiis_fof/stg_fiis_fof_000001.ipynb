-- %%
%sql
CREATE TABLE IF NOT EXISTS product_dev.financas.stg_scoring_fof (
  ticker STRING NOT NULL,
  data_referencia DATE NOT NULL,
  preco_atual DOUBLE NOT NULL,
  valor_patrimonial_cota DOUBLE NOT NULL,
  p_vp DOUBLE NOT NULL,
  dividend_yield_12m DOUBLE NOT NULL,
  duplo_desconto_estimado DOUBLE,
  taxa_administracao_ano DOUBLE,
  score_final DOUBLE,
  posicao_ranking INT,
  data_calculo TIMESTAMP NOT NULL
)
USING DELTA;

-- %%
%sql
COMMENT ON TABLE product_dev.financas.stg_scoring_fof 
IS 'Tabela da camada Silver contendo o cálculo de indicadores fundamentais, duplo desconto e classificação de ranking para FIIs do segmento de Fundos de Fundos (FoFs).';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN ticker COMMENT 'Código de negociação do FII de Fundos de Fundos (ex: BCIA11).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN data_referencia COMMENT 'Data base dos dados utilizados para o cálculo (geralmente fim do mês).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN preco_atual COMMENT 'Último preço de fechamento de mercado do fundo.';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN valor_patrimonial_cota COMMENT 'Valor patrimonial líquido do fundo dividido pela quantidade de cotas.';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN p_vp COMMENT 'Relação Preço sobre Valor Patrimonial. Indica o nível de desconto sobre a carteira interna do FoF.';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN dividend_yield_12m COMMENT 'Soma dos dividendos distribuídos nos últimos 12 meses dividida pelo preço atual (em %).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN duplo_desconto_estimado COMMENT 'Estimativa matemática do desconto sobre desconto (Desconto do FoF + Desconto médio dos FIIs investidos).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN taxa_administracao_ano COMMENT 'Taxa de administração e gestão anual cobrada pelo fundo (em %).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN score_final COMMENT 'Nota final padronizada calculada pelo modelo para classificação do FoF (0 a 100).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN posicao_ranking COMMENT 'Posição do fundo no ranking geral de FoFs com base no score_final (1º, 2º, 3º...).';
ALTER TABLE product_dev.financas.stg_scoring_fof ALTER COLUMN data_calculo COMMENT 'Data e hora em que os indicadores e o ranking foram calculados pelo pipeline.';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_fof SET TAGS (
  'environment' = 'development',
  'domain' = 'investments',
  'project' = 'portfolio_analytics',
  'owner' = 'data_engineer_study',
  'type' = 'silver'
);
