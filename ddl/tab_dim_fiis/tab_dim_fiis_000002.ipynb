-- %%
%sql
ALTER TABLE product_dev.financas.dim_fundo_imobiliario 
ADD COLUMNS (
  cnpj STRING COMMENT 'CNPJ oficial do fundo limpo sem máscara',
  codigo_isin STRING COMMENT 'Código internacional de identificação do ativo',
  nome_fundo_cvm STRING COMMENT 'Razão social oficial registrada na CVM',
  administrador STRING COMMENT 'Nome da instituição administradora do fundo',
  data_carga TIMESTAMP COMMENT 'Data e hora em que o registro foi enriquecido via CVM'
);
