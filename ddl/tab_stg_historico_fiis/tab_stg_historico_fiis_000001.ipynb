-- %%
%sql
CREATE TABLE IF NOT EXISTS product_dev.financas.stg_historico_cotacoes_fiis (
  ticker STRING NOT NULL,
  data_pregao DATE NOT NULL,
  preco_abertura DOUBLE,
  preco_maximo DOUBLE,
  preco_minimo DOUBLE,
  preco_fechamento DOUBLE NOT NULL,
  preco_fechamento_ajustado DOUBLE,
  volume_negociado BIGINT,
  proventos_pagos DOUBLE DEFAULT 0.0,
  data_carga TIMESTAMP NOT NULL
)
USING DELTA;

-- %%
%sql
COMMENT ON TABLE product_dev.financas.stg_historico_cotacoes_fiis 
IS 'Tabela de staging para armazenamento do histórico de séries temporais diárias (cotações, volumes e proventos) dos FIIs obtidos via Yahoo Finance.';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN ticker COMMENT 'Código de negociação do FII na B3 (ex: HGLG11).';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN data_pregao COMMENT 'Data correspondente ao dia do pregão do mercado.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN preco_abertura COMMENT 'Preço de abertura do fundo no dia do pregão.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN preco_maximo COMMENT 'Maior preço atingido pela cota durante o pregão.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN preco_minimo COMMENT 'Menor preço atingido pela cota durante o pregão.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN preco_fechamento COMMENT 'Preço final de fechamento da cota no dia.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN preco_fechamento_ajustado COMMENT 'Preço de fechamento ajustado por desdobramentos, agrupamentos e distribuições (ajustado pelo Yahoo Finance).';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN volume_negociado COMMENT 'Quantidade total de cotas e negócios movimentados no dia.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN proventos_pagos COMMENT 'Valor de dividendos ou rendimentos distribuídos por cota com data ex neste dia.';
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis ALTER COLUMN data_carga COMMENT 'Data e hora em que este registro foi inserido no nosso banco de dados.';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_historico_cotacoes_fiis SET TAGS (
  'environment' = 'development',
  'domain' = 'investments',
  'project' = 'portfolio_analytics',
  'owner' = 'data_engineer_study',
  'type' = 'staging'
);
