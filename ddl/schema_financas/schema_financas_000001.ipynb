# %%
CREATE SCHEMA IF NOT EXISTS product_dev.financas
COMMENT 'Ambiente de desenvolvimento e estudos focado em engenharia de dados, simulacoes de mercado e analise de fundos de investimento imobiliario (FIIs) para portfolio.';

# %%
ALTER SCHEMA product_dev.financas SET TAGS (
  'environment' = 'development',
  'domain' = 'investments',
  'project' = 'portfolio_analytics',
  'owner' = 'data_engineer_study'
);
