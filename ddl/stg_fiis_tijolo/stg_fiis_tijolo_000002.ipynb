-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_tijolo
ADD COLUMNS (
  segmento_alvo STRING COMMENT 'Segmento de atuação padronizado do FII de Tijolo (ex: Logística, Shopping, Lajes Corporativas)'
);
