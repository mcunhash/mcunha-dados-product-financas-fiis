-- %%
%sql
CREATE TABLE IF NOT EXISTS product_dev.financas.stg_scoring_tijolo (
  ticker STRING NOT NULL,
  data_referencia DATE NOT NULL,
  preco_atual DOUBLE NOT NULL,
  valor_patrimonial_cota DOUBLE NOT NULL,
  p_vp DOUBLE NOT NULL,
  dividend_yield_12m DOUBLE NOT NULL,
  vacancia_fisica DOUBLE NOT NULL,
  preco_m2_patrimonial DOUBLE,
  qtd_imoveis INT,
  score_final DOUBLE,
  posicao_ranking INT,
  data_calculo TIMESTAMP NOT NULL
)
USING DELTA;

-- %%
%sql
COMMENT ON TABLE product_dev.financas.stg_scoring_tijolo 
IS 'Tabela da camada Silver contendo o cálculo de indicadores fundamentais, score operacional e classificação de ranking para FIIs do segmento de Tijolo.';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN ticker COMMENT 'Código de negociação do FII de Tijolo (ex: HGLG11).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN data_referencia COMMENT 'Data base dos dados utilizados para o cálculo (geralmente fim do mês).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN preco_atual COMMENT 'Último preço de fechamento de mercado do fundo.';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN valor_patrimonial_cota COMMENT 'Valor patrimonial real do fundo dividido pela quantidade de cotas.';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN p_vp COMMENT 'Relação Preço sobre Valor Patrimonial. Indica ágio (acima de 1) ou desconto (abaixo de 1).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN dividend_yield_12m COMMENT 'Soma dos dividendos distribuídos nos últimos 12 meses dividida pelo preço atual (em %).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN vacancia_fisica COMMENT 'Percentual de área bruta locável (ABL) que está desocupada nos imóveis do fundo (em %).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN preco_m2_patrimonial COMMENT 'Valor do metro quadrado dos imóveis com base na avaliação patrimonial (Valor Patrimonial / ABL total).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN qtd_imoveis COMMENT 'Quantidade total de ativos imobiliários físicos que compõem o portfólio do fundo.';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN score_final COMMENT 'Nota final padronizada calculada pelo modelo multicritério para classificação do fundo (geralmente de 0 a 100).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN posicao_ranking COMMENT 'Posição do fundo no ranking geral de Tijolo com base no score_final (1º, 2º, 3º...).';
ALTER TABLE product_dev.financas.stg_scoring_tijolo ALTER COLUMN data_calculo COMMENT 'Data e hora em que os indicadores e o ranking foram calculados pelo pipeline.';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_tijolo SET TAGS (
  'environment' = 'development',
  'domain' = 'investments',
  'project' = 'portfolio_analytics',
  'owner' = 'data_engineer_study',
  'type' = 'silver'
);
