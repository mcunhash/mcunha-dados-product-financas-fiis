-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_tijolo
ADD COLUMNS (
  total_cotistas INT COMMENT 'Quantidade total de cotistas do fundo obtida via CVM',
  alavancagem_percentual DOUBLE COMMENT 'Percentual de obrigações/dívidas sobre o ativo total do fundo',
  caixa_percentual DOUBLE COMMENT 'Percentual de recursos mantidos em caixa/disponibilidades'
);
