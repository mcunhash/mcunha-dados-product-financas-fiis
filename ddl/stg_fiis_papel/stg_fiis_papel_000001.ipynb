-- %%
%sql
CREATE TABLE IF NOT EXISTS product_dev.financas.stg_scoring_papel (
  ticker STRING NOT NULL,
  data_referencia DATE NOT NULL,
  preco_atual DOUBLE NOT NULL,
  valor_patrimonial_cota DOUBLE NOT NULL,
  p_vp DOUBLE NOT NULL,
  dividend_yield_12m DOUBLE NOT NULL,
  taxa_media_ipca DOUBLE,
  taxa_media_cdi DOUBLE,
  max_concentracao_devedor DOUBLE,
  score_final DOUBLE,
  posicao_ranking INT,
  data_calculo TIMESTAMP NOT NULL
)
USING DELTA;

-- %%
%sql
COMMENT ON TABLE product_dev.financas.stg_scoring_papel 
IS 'Tabela da camada Silver contendo o cálculo de indicadores fundamentais, score de crédito/risco e classificação de ranking para FIIs do segmento de Papel (Recebíveis Imobiliários).';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN ticker COMMENT 'Código de negociação do FII de Papel (ex: KNIP11).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN data_referencia COMMENT 'Data base dos dados utilizados para o cálculo (geralmente fim do mês).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN preco_atual COMMENT 'Último preço de fechamento de mercado do fundo.';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN valor_patrimonial_cota COMMENT 'Valor patrimonial líquido do fundo dividido pela quantidade de cotas.';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN p_vp COMMENT 'Relação Preço sobre Valor Patrimonial. Para papel, valores distantes de 1.0 indicam distorções severas.';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN dividend_yield_12m COMMENT 'Soma dos dividendos distribuídos nos últimos 12 meses dividida pelo preço atual (em %).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN taxa_media_ipca COMMENT 'Taxa média de juros reais recebida nos CRIs atrelados ao IPCA (ex: IPCA + 6.5%).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN taxa_media_cdi COMMENT 'Taxa média de juros recebida nos CRIs atrelados ao CDI (ex: CDI + 2.0%).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN max_concentracao_devedor COMMENT 'Maior percentual de exposição do patrimônio líquido do fundo a um único devedor (indica risco de inadimplência).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN score_final COMMENT 'Nota final padronizada calculada pelo modelo multicritério de crédito para classificação do fundo (0 a 100).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN posicao_ranking COMMENT 'Posição do fundo no ranking geral de Papel com base no score_final (1º, 2º, 3º...).';
ALTER TABLE product_dev.financas.stg_scoring_papel ALTER COLUMN data_calculo COMMENT 'Data e hora em que os indicadores e o ranking foram calculados pelo pipeline.';

-- %%
%sql
ALTER TABLE product_dev.financas.stg_scoring_papel SET TAGS (
  'environment' = 'development',
  'domain' = 'investments',
  'project' = 'portfolio_analytics',
  'owner' = 'data_engineer_study',
  'type' = 'silver'
);
