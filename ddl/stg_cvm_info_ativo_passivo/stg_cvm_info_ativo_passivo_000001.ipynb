# %%
# %sql
CREATE TABLE IF NOT EXISTS product_dev.financas.stg_cvm_informe_ativo_passivo (
  ticker STRING NOT NULL,
  data_referencia DATE NOT NULL,
  cnpj STRING NOT NULL,
  total_investido DOUBLE NOT NULL,
  valor_imoveis_renda DOUBLE,
  valor_imoveis_desenvolvimento DOUBLE,
  valor_caixa_disponibilidades DOUBLE,
  valor_investido_cri_cra DOUBLE,
  valor_investido_lci_lca DOUBLE,
  valor_investido_outros_fiis DOUBLE,
  valor_investido_acoes DOUBLE,
  total_passivo_obrigacoes DOUBLE,
  data_carga TIMESTAMP NOT NULL
)
USING DELTA;

# %%
# %sql
COMMENT ON TABLE product_dev.financas.stg_cvm_informe_ativo_passivo 
IS 'Tabela da camada Silver contendo a composicao contabilidade do Ativo e Passivo (balanco patrimonial) dos FIIs detalhando o direcionamento dos recursos (imoveis, CRIs, caixa, FoFs).';

# %%
# %sql
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN ticker COMMENT 'Codigo de negociacao do FII na B3 (ex: HGLG11).';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN data_referencia COMMENT 'Data de competencia do informe mensal contendo a foto do balanco.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN cnpj COMMENT 'CNPJ oficial do fundo limpo sem mascara utilizado como chave de cruzamento.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN total_investido COMMENT 'Montante financeiro total alocado em ativos financeiros e imobiliarios pelo fundo.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_imoveis_renda COMMENT 'Valor contabil dos imoveis prontos destinados a geracao de renda (Tijolo).';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_imoveis_desenvolvimento COMMENT 'Valor contabil de terrenos ou imoveis em construcao destinados a venda ou renda futura.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_caixa_disponibilidades COMMENT 'Montante financeiro liquido mantido em caixa ou equivalentes de caixa de liquidez imediata.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_investido_cri_cra COMMENT 'Valor alocado em Certificados de Recebiveis Imobiliarios ou do Agronegocio (Papel).';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_investido_lci_lca COMMENT 'Valor alocado em Letras de Credito Imobiliario ou do Agronegocio.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_investido_outros_fiis COMMENT 'Valor total investido em cotas de outros fundos imobiliarios (FoF).';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN valor_investido_acoes COMMENT 'Valor investido em acoes de sociedades que realizem atividades do objeto do FII.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN total_passivo_obrigacoes COMMENT 'Soma das obrigacoes, passivos e dividas a pagar do fundo.';
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo ALTER COLUMN data_carga COMMENT 'Data e hora em que o registro foi tratado e persistido pelo pipeline.';

# %%
# %sql
ALTER TABLE product_dev.financas.stg_cvm_informe_ativo_passivo SET TAGS (
  'environment' = 'development',
  'domain' = 'investments',
  'project' = 'portfolio_analytics',
  'owner' = 'data_engineer_study',
  'type' = 'silver'
);
