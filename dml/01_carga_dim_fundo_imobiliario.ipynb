-- %%
%python
# dml/01_carga_dim_fundo_imobiliario.ipynb
# MAGIC %pip install pandas lxml # Garante as dependências necessárias no Serverless Compute do Notebook

# %%
import pandas as pd

# 1. Definição da função de classificação inteligente
def classificar_tipo_fii(row):
    razao = str(row["Razão Social"]).lower()
    fundo = str(row["Fundo"]).lower()
    ticker = str(row["Ticker"]).upper().strip()

    # Mapeamento Direto por Ticker
    mapeamento_direto = {
        "ATWN11": "Tijolo (Logística)", "BZEL11": "Tijolo (Logística)", "BTSI11": "Tijolo (Logística)", 
        "ESTQ11": "Tijolo (Logística)", "TRXF11": "Tijolo (Logística)", "TRXB11": "Tijolo (Logística)",
        "BBRC11": "Tijolo (Lajes Corporativas)", "BGRB11": "Tijolo (Lajes Corporativas)", "BGRJ11": "Tijolo (Lajes Corporativas)",
        "BRSE11": "Tijolo (Lajes Corporativas)", "FATN11": "Tijolo (Lajes Corporativas)", "RTEL11": "Tijolo (Lajes Corporativas)",
        "CXCO11": "Tijolo (Lajes Corporativas)", "CBOP11": "Tijolo (Lajes Corporativas)", "BLCA11": "Tijolo (Lajes Corporativas)",
        "CVFL11": "Tijolo (Lajes Corporativas)", "CTXT11": "Tijolo (Lajes Corporativas)", "CENU11": "Tijolo (Lajes Corporativas)",
        "FLMA11": "Tijolo (Lajes Corporativas)", "ELDO11": "Tijolo (Lajes Corporativas)", "FMOF11": "Tijolo (Lajes Corporativas)",
        "WTSP11": "Tijolo (Lajes Corporativas)", "HCTB11": "Tijolo (Lajes Corporativas)", "TMPS11": "Tijolo (Lajes Corporativas)",
        "RNGO11": "Tijolo (Lajes Corporativas)", "SPTW11": "Tijolo (Lajes Corporativas)", "BLMO11": "Tijolo (Lajes Corporativas)",
        "CFII11": "Papel (Recebíveis Imobiliários)", "CFHF11": "Papel (Recebíveis Imobiliários)", "VRTA11": "Papel (Recebíveis Imobiliários)",
        "HCTR11": "Papel (Recebíveis Imobiliários)", "ITIP11": "Papel (Recebíveis Imobiliários)", "SAPI11": "Papel (Recebíveis Imobiliários)",
        "URPR11": "Papel (Recebíveis Imobiliários)", "VGRI11": "Papel (Recebíveis Imobiliários)",
        "AURB11": "Desenvolvimento / Residencial", "APXU11": "Desenvolvimento / Residencial", "EIRA11": "Desenvolvimento / Residencial",
        "ARTE11": "Desenvolvimento / Residencial", "BINR11": "Desenvolvimento / Residencial", "BRIM11": "Desenvolvimento / Residencial",
        "BRIP11": "Desenvolvimento / Residencial", "BIPD11": "Desenvolvimento / Residencial", "BIPE11": "Desenvolvimento / Residencial",
        "MCMV11": "Desenvolvimento / Residencial", "KONG11": "Desenvolvimento / Residencial", "LKDV11": "Desenvolvimento / Residencial",
        "HOSI11": "Desenvolvimento / Residencial", "PABY11": "Desenvolvimento / Residencial", "VTPA11": "Desenvolvimento / Residencial",
        "FPNG11": "Desenvolvimento / Residencial", "RZTR11": "Desenvolvimento / Residencial", "ROOF11": "Desenvolvimento / Residencial",
        "HOMS11": "Desenvolvimento / Residencial", "FISC11": "Desenvolvimento / Residencial", "SOFF11": "Desenvolvimento / Residencial",
        "VERE11": "Desenvolvimento / Residencial", "FIVN11": "Desenvolvimento / Residencial", "INRD11": "Desenvolvimento / Residencial",
        "JCDB11": "Desenvolvimento / Residencial", "JCDA11": "Desenvolvimento / Residencial", "KRES11": "Desenvolvimento / Residencial",
        "KCRE11": "Desenvolvimento / Residencial", "KFEN11": "Desenvolvimento / Residencial", "LPLP11": "Desenvolvimento / Residencial",
        "LRED11": "Desenvolvimento / Residencial", "LSOI11": "Desenvolvimento / Residencial", "LSII11": "Desenvolvimento / Residencial",
        "LSOP11": "Desenvolvimento / Residencial", "LOFT11": "Desenvolvimento / Residencial", "MMVE11": "Desenvolvimento / Residencial",
        "NVIF11": "Desenvolvimento / Residencial", "OBAL11": "Desenvolvimento / Residencial", "OXRL11": "Desenvolvimento / Residencial",
        "PQAG11": "Desenvolvimento / Residencial", "PATB11": "Desenvolvimento / Residencial", "PEMA11": "Desenvolvimento / Residencial",
        "PRSN11": "Desenvolvimento / Residencial", "PCAS11": "Desenvolvimento / Residencial", "PRSV11": "Desenvolvimento / Residencial",
        "FPAB11": "Desenvolvimento / Residencial", "FIIP11": "Desenvolvimento / Residencial", "RBRD11": "Desenvolvimento / Residencial",
        "RBTS11": "Desenvolvimento / Residencial", "SHIP11": "Desenvolvimento / Residencial", "BOAT11": "Desenvolvimento / Residencial",
        "RINV11": "Desenvolvimento / Residencial", "FRRE11": "Desenvolvimento / Residencial", "RZAK11": "Desenvolvimento / Residencial",
        "RZAT11": "Desenvolvimento / Residencial", "RZLC11": "Desenvolvimento / Residencial", "RJDA11": "Desenvolvimento / Residencial",
        "SEQR11": "Desenvolvimento / Residencial", "SPAF11": "Desenvolvimento / Residencial", "LTMT11": "Desenvolvimento / Residencial",
        "DVLP11": "Desenvolvimento / Residencial", "DVLT11": "Desenvolvimento / Residencial", "STRX11": "Desenvolvimento / Residencial",
        "TSNC11": "Desenvolvimento / Residencial", "TCPF11": "Desenvolvimento / Residencial", "TORD11": "Desenvolvimento / Residencial",
        "VVMR11": "Desenvolvimento / Residencial", "VVRI11": "Desenvolvimento / Residencial", "YUFI11": "Desenvolvimento / Residencial",
        "ZAVI11": "Desenvolvimento / Residencial",
        "ALZR11": "Híbrido / Multiestratégia", "CEBB11": "Híbrido / Multiestratégia", "BNFS11": "Híbrido / Multiestratégia",
        "BFCC11": "Híbrido / Multiestratégia", "CPOF11": "Híbrido / Multiestratégia", "CIXM11": "Híbrido / Multiestratégia",
        "CSMC11": "Híbrido / Multiestratégia", "DAMA11": "Híbrido / Multiestratégia", "DLMT11": "Híbrido / Multiestratégia",
        "DAMT11": "Híbrido / Multiestratégia", "DOVL11": "Híbrido / Multiestratégia", "EDGE11": "Híbrido / Multiestratégia",
        "EGYR11": "Híbrido / Multiestratégia", "ERPA11": "Híbrido / Multiestratégia", "KEVE11": "Híbrido / Multiestratégia",
        "EXES11": "Híbrido / Multiestratégia", "EURO11": "Híbrido / Multiestratégia", "OPTM11": "Híbrido / Multiestratégia",
        "FLNR11": "Híbrido / Multiestratégia", "FCFL11": "Híbrido / Multiestratégia", "RECT11": "Híbrido / Multiestratégia",
        "APXR11": "Híbrido / Multiestratégia", "CXAG11": "Híbrido / Multiestratégia", "CXCI11": "Híbrido / Multiestratégia",
        "NVHO11": "Híbrido / Multiestratégia", "VTPL11": "Híbrido / Multiestratégia", "SMRE11": "Híbrido / Multiestratégia",
        "FIIC11": "Híbrido / Multiestratégia", "TCIN11": "Híbrido / Multiestratégia", "GCOI11": "Híbrido / Multiestratégia",
        "RCFA11": "Híbrido / Multiestratégia", "ATCR11": "Híbrido / Multiestratégia", "HIRE11": "Híbrido / Multiestratégia",
        "HUSI11": "Híbrido / Multiestratégia", "ICNE11": "Híbrido / Multiestratégia", "IMMB11": "Híbrido / Multiestratégia",
        "ITIT11": "Híbrido / Multiestratégia", "IBBP11": "Híbrido / Multiestratégia", "IRIM11": "Híbrido / Multiestratégia",
        "JFLR11": "Híbrido / Multiestratégia", "JCSC11": "Híbrido / Multiestratégia", "JPRD11": "Híbrido / Multiestratégia",
        "JSAF11": "Híbrido / Multiestratégia", "JTPR11": "Híbrido / Multiestratégia", "LASC11": "Híbrido / Multiestratégia",
        "LIFE11": "Híbrido / Multiestratégia", "MAGM11": "Híbrido / Multiestratégia", "MCRE11": "Híbrido / Multiestratégia",
        "MOSO11": "Híbrido / Multiestratégia", "NAVT11": "Híbrido / Multiestratégia", "EAGL11": "Híbrido / Multiestratégia",
        "OCRE11": "Híbrido / Multiestratégia", "FTCE11": "Híbrido / Multiestratégia", "VTVI11": "Híbrido / Multiestratégia",
        "RBFY11": "Híbrido / Multiestratégia", "SCPF11": "Híbrido / Multiestratégia", "REIT11": "Híbrido / Multiestratégia",
        "SPGM11": "Híbrido / Multiestratégia", "SPG211": "Híbrido / Multiestratégia", "SPXT11": "Híbrido / Multiestratégia",
        "STYI11": "Híbrido / Multiestratégia", "SURE11": "Híbrido / Multiestratégia", "SPMO11": "Híbrido / Multiestratégia",
        "TIOM11": "Híbrido / Multiestratégia", "TVRI11": "Híbrido / Multiestratégia", "TJKB11": "Híbrido / Multiestratégia",
        "MGHT11": "Híbrido / Multiestratégia", "SPDE11": "Híbrido / Multiestratégia", "WHGR11": "Híbrido / Multiestratégia",
        "XLPR11": "Híbrido / Multiestratégia", "ZIFI11": "Híbrido / Multiestratégia",
        "VNSS11": "Fundo de Fundos (FoF)",
        "BPDR11": "Tijolo (Segmentos Específicos: Saúde/Hotel/Educação)",
        "BPMW11": "Tijolo (Segmentos Específicos: Saúde/Hotel/Educação)",
        "SALI11": "Tijolo (Segmentos Específicos: Saúde/Hotel/Educação)"
    }

    if ticker in mapeamento_direto:
        return mapeamento_direto[ticker]

    # Regras Genéricas baseadas em termos chaves
    elif any(term in razao for term in ["fundo de fundos", "cotas de fundos", "fic", "fund of funds", "cotas de fundo"]) or "fof" in fundo or "fof" in razao:
        return "Fundo de Fundos (FoF)"
    elif any(term in razao for term in ["recebíveis", "recebiveis", "crédito", "credito", "securities", "juros real", "índices de preços", "high yield", "high grade", "ipca", "cdi", "papel"]) or "cri" in fundo or "cri" in razao:
        return "Papel (Recebíveis Imobiliários)"
    elif any(term in razao for term in ["logística", "logistica", "galpões", "galpoes", "industrial", "last mile"]) or "log" in fundo or "log" in razao:
        return "Tijolo (Logística)"
    elif any(term in razao for term in ["shopping", "mall", "malls", "retail", "varejo", "ancar", "supermercado"]) or "shopping" in fundo:
        return "Tijolo (Shopping)"
    elif any(term in razao for term in ["corporate", "offices", "lajes", "edifício", "edificio", "escritórios", "escritorios", "properties", "tower", "torre", "parque da cidade", "cenesp"]) or "offices" in fundo:
        return "Tijolo (Lajes Corporativas)"
    elif any(term in razao for term in ["residencial", "desenvolvimento", "incorporação", "incorporacao", "retrofit", "lote", "loteamento", "permuta", "housing", "living", "urbanos", "unidades", "real estate equity"]) or "residencial" in fundo:
        return "Desenvolvimento / Residencial"
    elif any(term in razao for term in ["hospital", "hospitalar", "saúde", "saude", "hotel", "hoteis", "hotéis", "educacional", "escola", "death care"]):
        return "Tijolo (Segmentos Específicos: Saúde/Hotel/Educação)"
    elif any(term in razao for term in ["multiestratégia", "multiestrategia", "multi ativos", "multiativos", "hedge", "híbrido", "hibrido", "oportunidades", "renda urbana", "renda imobiliária", "renda imobiliaria"]):
        return "Híbrido / Multiestratégia"
    elif any(term in razao for term in ["agro", "terras", "solar", "energia", "infra", "cedae"]):
        return "Agro / Infraestrutura / Energia"
    else:
        return "Outros / Não Especificado"

# %%
# 2. Leitura do arquivo bruto a partir do Volume do Unity Catalog
# Note que o caminho agora utiliza a pasta virtual do Unity Catalog (/Volumes/...)
caminho_arquivo = "/Volumes/product_dev/financas/raw_data/fundosListados.csv"
df_pandas = pd.read_csv(caminho_arquivo, sep=";", encoding="latin1", index_col=False)
df_pandas = df_pandas.dropna(how="all", axis=1)

# Aplica a higienização e classificação do modelo
df_pandas["Ticker"] = df_pandas["Código"].astype(str).str.strip() + "11"
df_pandas["Classificação"] = df_pandas.apply(classificar_tipo_fii, axis=1)

# %%
# 3. Conversão para Spark DataFrame (para escrita no banco Delta)
df_pandas = df_pandas.rename(columns={
    "Razão Social": "razao_social",
    "Fundo": "nome_fundo",
    "Código": "codigo_fundo",
    "Ticker": "ticker",
    "Classificação": "classificacao"
})

# Seleciona apenas as colunas mapeadas no nosso DDL da dim_fundo_imobiliario
df_final = df_pandas[["ticker", "razao_social", "nome_fundo", "codigo_fundo", "classificacao"]]

# Converte de Pandas para Spark DataFrame
spark_df = spark.createDataFrame(df_final)

# Cria uma view temporária da sessão Spark
spark_df.createOrReplaceTempView("temp_fii_classificados")

# %%
# 4. Execução da f-string de Carga com INSERT OVERWRITE
catalogo = "product_dev"
schema = "financas"
tabela_destino = "dim_fundo_imobiliario"

# Cria a string de query dinâmica de carga
qry_insert_dim_fiis = f"""
  INSERT OVERWRITE {catalogo}.{schema}.{tabela_destino}
  SELECT 
    ticker,
    razao_social,
    nome_fundo,
    codigo_fundo,
    classificacao
  FROM temp_fii_classificados
"""

print(f"Executando carga de dados em: {catalogo}.{schema}.{tabela_destino}...")

# Executa o INSERT OVERWRITE no motor Spark/Photon do Databricks
spark.sql(qry_insert_dim_fiis)

print("✅ Carga finalizada com SUCESSO via INSERT OVERWRITE!")
